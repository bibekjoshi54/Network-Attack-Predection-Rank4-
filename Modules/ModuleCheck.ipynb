# %%
# %matplotlib notebook
import DataAbstraction as DA
import level1 as l1
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


plt.style.use('bmh')
# Out:
# /home/ab/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
data = DA.Data(pd.read_csv('../Data/train_data.csv'),pd.read_csv('../Data/test_data.csv'))
# Out:
# train : (169307, 43)
# test: (91166, 42)

# %%
# data.train.info()
pd.read_csv('../Data/test_data.csv')
# Out:
#       connection_id  cont_1  cont_2  cont_3  cont_4  cont_5  cont_6  cont_7  \
# 0           cxcon_2       0     331    6085    0.00     0.0    0.00     0.0
# 1           cxcon_5       0     520       0    0.00     0.0    0.00     0.0
# 2           cxcon_8       0    1032       0    0.00     0.0    0.00     0.0
# 3          cxcon_11       0    1032       0    0.00     0.0    0.00     0.0
# 4          cxcon_14       0    1032       0    0.00     0.0    0.00     0.0
# 5          cxcon_17       0    1032       0    0.00     0.0    0.00     0.0
# 6          cxcon_20       0       0       0    0.00     0.0    1.00     1.0
# 7          cxcon_23       0     332     743    0.00     0.0    0.00     0.0
# 8          cxcon_26       0    1032       0    0.00     0.0    0.00     0.0
# 9          cxcon_29       0    1032       0    0.00     0.0    0.00     0.0
# 10         cxcon_32       0    1032       0    0.00     0.0    0.00     0.0
# ...

# %%
# data.distView(data.train['cont_1'])
# plt.figure(figsize=(9,8))
# sns.distplot(data.train['cont_1'], bins=50, hist_kws={'alpha': 0.4})
# data.train[data.getCustom('cat')].hist(figsize=(16, 20), bins=10, xlabelsize=8, ylabelsize=8);

# %%
# plt.show()

# %%
# data.train[data.getCustom('cont')].hist(figsize=(16, 20), bins=100, xlabelsize=8, ylabelsize=8);

# %%
# fig, axes = plt.subplots(round(len(data.getCustom('cat')) / 3), 3, figsize=(12, 30))

# for i, ax in enumerate(fig.axes):
#     if i < len(data.getCustom('cat')):
# #         ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
#         sns.countplot(x=data.train[data.getCustom('cat')].columns[i], alpha=0.7, data=data.train[data.getCustom('cat')], ax=ax)

# fig.tight_layout()

# %%
# fig, axes = plt.subplots(round(len(data.getCustom('cat')) / 3), 3, figsize=(12, 30))

# for i, ax in enumerate(fig.axes):
#     if i < len(data.getCustom('cat')):
# #         ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
#         sns.countplot(x=data.test[data.getCustom('cat')].columns[i], alpha=0.7, data=data.test[data.getCustom('cat')], ax=ax)

# fig.tight_layout()

# %%
# for i in data.getCustom('cat'):
#     print(i)
#     print('Test')
#     print(data.test[i].value_counts())
#     print('train')
#     print(data.train[i].value_counts())
#     print('\n')

# %%
a = ['cat_' + str(i) for i in range(4,9)] + ['cat_' + str(i) for i in range(10,20)]
data.drop(a)

# %%
data.scaler(data.getCustom('cont'))

# %%
data.decomposition()

# %%
lvl1 = l1.Level1(data,'EntireData')

# %%
# import pickle

# %%
# a = pickle.load(open('Models/InitialCheck1511451512level10.lvl1','rb'))

# %%
a = lvl1.fit()

# %%
predtrain, predtest = lvl1.generate()

# %%
lvl1.clasifier

# %%
predtrain

# %%
data.train['lvl1_0'] = predtrain[0]
data.train['lvl1_1'] = predtrain[1]
data.train['lvl1_2'] = predtrain[2]
data.test['lvl1_0'] = predtest[0]
data.test['lvl1_1'] = predtest[1]
data.test['lvl1_2'] = predtest[2]

# %%
data.train.columns

# %%
import level2 as l2

# %%
lvl2 = l2.level2(data.train[data.getCustom('lvl')],data.train['target'],data.test[data.getCustom('lvl1')])

# %%
lvl2.fit()

# %%
a = lvl2.pred()

# %%
a

# %%
set(a)

# %%
sub = pd.read_csv('../Data/sample_submission.csv')
sub['target'] = a
sub['target'] = sub['target'].astype(int)
sub.to_csv('NEW.csv', index=False)

# %%
import pandas as pd
a= pd.read_csv('../Data/train_data.csv')

# %%
a.shape

# %%
len(a['target'])

# %%
markerTrain = round(data.train.shape[0] / 5) # Single Fold size for train
markerTest = round(data.test.shape[0] /5)    # Single Fold Size for test
queue = [i + 1 for i in range(5)]
train_index = []
test_index = []
for i in range(5):
    if i != 4:
        test_index.append(range(markerTest*(i),markerTest*(i+1)))
        train_index.append(range(markerTrain*(i),markerTrain*(i+1)))
    else:
        test_index.append(range(markerTest*(i),data.test.shape[0]))
        train_index.append(range(markerTrain*(i),data.train.shape[0]))

# %%
test_index
# Out:
# [range(0, 18233),
#  range(18233, 36466),
#  range(36466, 54699),
#  range(54699, 72932),
#  range(72932, 91166)]

# %%
train_index
# Out:
# [range(0, 33861),
#  range(33861, 67722),
#  range(67722, 101583),
#  range(101583, 135444),
#  range(135444, 169307)]
